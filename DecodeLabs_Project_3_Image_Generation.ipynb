# %%
# !pip -q install diffusers transformers accelerate safetensors

# %%
import torch
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]

# %%
prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
plt.imshow(image)
plt.axis("off")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
image.save("generated_image.png")

# %%
from google.colab import files

files.download("generated_image.png")

# %%
prompt = "A dragon flying over snowy mountains"

image = pipe(
    prompt,
    height=512,
    width=512
).images[0]

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "A futuristic city at sunset"

images = pipe(
    prompt,
    num_images_per_prompt=4
).images

fig, axes = plt.subplots(1,4, figsize=(16,5))

for ax,img in zip(axes,images):
    ax.imshow(img)
    ax.axis("off")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A magical forest with glowing butterflies"

# %%
prompt = "Iron Man made entirely from glass"

# %%
prompt = "A Pakistani village in Studio Ghibli style"

# %%
prompt = input("Enter Prompt : ")

image = pipe(prompt).images[0]

image
# Out:
# Enter Prompt :  create me a picture of dragon
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.axis("off")
plt.title(prompt)
# Out:
# Text(0.5, 1.0, ' create me a picture of dragon')
